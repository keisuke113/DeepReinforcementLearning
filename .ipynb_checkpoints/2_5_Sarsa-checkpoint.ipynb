# %%
# Jupyterでmatplotlibを使用する宣言と、使用するライブラリの定義
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# 初期位置での迷路の様子
 
# 図を描く大きさと、図の変数名を宣言
fig = plt.figure(figsize=(5, 5))
ax = plt.gca()
 
# 赤い壁を描く
plt.plot([1, 1], [0, 1], color='red', linewidth=2)
plt.plot([1, 2], [2, 2], color='red', linewidth=2)
plt.plot([2, 2], [2, 1], color='red', linewidth=2)
plt.plot([2, 3], [1, 1], color='red', linewidth=2)
 
# 状態を示す文字S0～S8を描く
plt.text(0.5, 2.5, 'S0', size=14, ha='center')
plt.text(1.5, 2.5, 'S1', size=14, ha='center')
plt.text(2.5, 2.5, 'S2', size=14, ha='center')
plt.text(0.5, 1.5, 'S3', size=14, ha='center')
plt.text(1.5, 1.5, 'S4', size=14, ha='center')
plt.text(2.5, 1.5, 'S5', size=14, ha='center')
plt.text(0.5, 0.5, 'S6', size=14, ha='center')
plt.text(1.5, 0.5, 'S7', size=14, ha='center')
plt.text(2.5, 0.5, 'S8', size=14, ha='center')
plt.text(0.5, 2.3, 'START', ha='center')
plt.text(2.5, 0.3, 'GOAL', ha='center')
 
# 描画範囲の設定と目盛りを消す設定
ax.set_xlim(0, 3)
ax.set_ylim(0, 3)
plt.tick_params(axis='both', labelbottom=False, labelleft=False)
 
# 現在値S0に緑丸を描画する
line, = ax.plot([0.5], [2.5], marker="o", color='g', markersize=60)

# %%
# 初期の方策を決定するパラメータtheta_0を設定
 
# 行は状態0～7、列は移動方向で↑、→、↓、←を表す
theta_0 = np.array([[np.nan, 1, 1, np.nan],  # s0
                    [np.nan, 1, np.nan, 1],  # s1
                    [np.nan, np.nan, 1, 1],  # s2
                    [1, 1, 1, np.nan],  # s3
                    [np.nan, np.nan, 1, 1],  # s4
                    [1, np.nan, np.nan, np.nan],  # s5
                    [1, np.nan, np.nan, np.nan],  # s6
                    [1, 1, np.nan, np.nan],  # s7、※s8はゴールなので、方策はなし
                    ])

# %%
# 初期の行動価値関数Qを設定
 
[a, b] = theta_0.shape  # 行と列の数をa, bに格納
Q = np.random.rand(a, b) * theta_0
# *theta0をすることで要素ごとに掛け算をし、壁方向がnanになる

# %%
# 方策パラメータtheta_0をランダム方策piに変換する関数の定義
 
def simple_convert_into_pi_from_theta(theta):
    '''単純に割合を計算する'''
 
    [m, n] = theta.shape  # thetaの行列サイズを取得
    pi = np.zeros((m, n))
    for i in range(0, m):
        pi[i, :] = theta[i, :] / np.nansum(theta[i, :])  # 割合の計算
 
    pi = np.nan_to_num(pi)  # nanを0に変換
 
    return pi
 
# ランダム行動方策pi_0を求める
pi_0 = simple_convert_into_pi_from_theta(theta_0)

# %%
# ε-greedy法を実装
 
def get_action_and_s_next(s, Q, epsilon, pi_0):
    direction = ["up", "right", "down", "left"]
 
    # 行動を決める
    if np.random.rand() < epsilon:
        # εの確率でランダムに動く
        next_direction = np.random.choice(direction, p=pi_0[s, :])
    else:
        # Qの最大値の行動を採用する
        next_direction = direction[np.nanargmax(Q[s, :])]
 
    # 決めた行動で次の状態を決める
    if next_direction == "up":
        action = 0
        s_next = s - 3  # 上に移動するときは状態の数字が3小さくなる
    elif next_direction == "right":
        action = 1
        s_next = s + 1  # 右に移動するときは状態の数字が1大きくなる
    elif next_direction == "down":
        action = 2
        s_next = s + 3  # 下に移動するときは状態の数字が3大きくなる
    elif next_direction == "left":
        action = 3
        s_next = s - 1  # 左に移動するときは状態の数字が1小さくなる
 
    return [action, s_next]

# %%
# Sarsaによる行動価値関数Qの更新
 
def Sarsa(s, a, r, s_next, a_next, Q, eta, gamma):
 
    if s_next == 8:  # ゴールした場合
        Q[s, a] = Q[s, a] + eta * (r - Q[s, a])
 
    else:
        Q[s, a] = Q[s, a] + eta * (r + gamma * Q[s_next, a_next] - Q[s, a])
 
    return Q

# %%
# Sarsaで迷路を解く関数の定義、状態と行動の履歴および更新したQを出力
 
def goal_maze_ret_s_a_Q(Q, epsilon, eta, gamma, pi_0):
    s = 0  # スタート地点
    s_a_history = [[0, np.nan]]  # エージェントの移動を記録するリスト
 
    while (1):  # ゴールするまでループ
        [a, s_next] = get_action_and_s_next(s, Q, epsilon, pi_0)
        s_a_history[-1][1] = a
        # 現在の状態（つまり一番最後なのでindex=-1）に行動を代入
 
        s_a_history.append([s_next, np.nan])
        # 次の状態を代入。行動はまだ分からないのでnanにしておく
 
        # 報酬を与え,　次の行動を求めます
        if s_next == 8:
            r = 1  # ゴールにたどり着いたなら報酬を与える
            a_next = np.nan
        else:
            r = 0
            [a_next, _] = get_action_and_s_next(s_next, Q, epsilon, pi_0)
            # 実際行動しないですが、次の行動a_nextを求めます。
            # 返り値の_は、その変数は無視するという意味です
 
        # 価値関数を更新
        Q = Sarsa(s, a, r, s_next, a_next, Q, eta, gamma)
 
        # 終了判定
        if s_next == 8:  # ゴール地点なら終了
            break
        else:
            s = s_next
 
    return [s_a_history, Q]

# %%
# Sarsaで迷路を解く
eta = 0.1  # 学習率
gamma = 0.9  # 時間割引率
epsilon = 0.5  # ε-greedy法の初期値
v = np.nanmax(Q, axis=1)  # 状態ごとに価値の最大値を求める
is_continue = True
episode = 1
 
while is_continue:  # is_continueがFalseになるまで繰り返す
    print("エピソード:" + str(episode))
 
    # ε-greedyの値を少しずつ小さくする
    epsilon = epsilon / 2
 
    # Sarsaで迷路を解き、移動した履歴と更新したQを求める
    [s_a_history, Q] = goal_maze_ret_s_a_Q(Q, epsilon, eta, gamma, pi_0)
 
    # 状態価値の変化
    new_v = np.nanmax(Q, axis=1)  # 状態ごとに価値の最大値を求める
    print(np.sum(np.abs(new_v - v)))  # 状態価値の変化を出力
    v = new_v
 
    print("迷路を解くのにかかったステップ数は" + str(len(s_a_history) - 1) + "です")
 
    # 100エピソード繰り返す
    episode = episode + 1
    if episode > 100:
        break
# Out:
# エピソード:1
# 1.0198475590682214
# 迷路を解くのにかかったステップ数は66です
# エピソード:2
# 0.36550281270310925
# 迷路を解くのにかかったステップ数は82です
# エピソード:3
# 2.3540740604002903
# 迷路を解くのにかかったステップ数は780です
# エピソード:4
# 0.1136327212275785
# 迷路を解くのにかかったステップ数は32です
# エピソード:5
# 0.09015304347285169
# 迷路を解くのにかかったステップ数は18です
# エピソード:6
# 0.07981838778362893
# 迷路を解くのにかかったステップ数は12です
# エピソード:7
# 0.07434483925868607
# 迷路を解くのにかかったステップ数は12です
# エピソード:8
# 0.07281445110311102
# 迷路を解くのにかかったステップ数は10です
# エピソード:9
# 0.061240940462516935
# 迷路を解くのにかかったステップ数は4です
# エピソード:10
# 0.07068660736047327
# 迷路を解くのにかかったステップ数は10です
# エピソード:11
# 0.05953656097311816
# 迷路を解くのにかかったステップ数は4です
# エピソード:12
# 0.05805761580178975
# 迷路を解くのにかかったステップ数は4です
# エピソード:13
# 0.05746406383373015
# 迷路を解くのにかかったステップ数は4です
# エピソード:14
# 0.05681540155898762
# 迷路を解くのにかかったステップ数は4です
# エピソード:15
# 0.0561076220710347
# 迷路を解くのにかかったステップ数は4です
# エピソード:16
# 0.055338196290648234
# 迷路を解くのにかかったステップ数は4です
# エピソード:17
# 0.05450600204580225
# 迷路を解くのにかかったステップ数は4です
# エピソード:18
# 0.05361121438862332
# 迷路を解くのにかかったステップ数は4です
# エピソード:19
# 0.052655171399169254
# 迷路を解くのにかかったステップ数は4です
# エピソード:20
# 0.051640226487565
# 迷路を解くのにかかったステップ数は4です
# エピソード:21
# 0.05056959557024615
# 迷路を解くのにかかったステップ数は4です
# エピソード:22
# 0.049447205362922464
# 迷路を解くのにかかったステップ数は4です
# エピソード:23
# 0.04827754731786854
# 迷路を解くのにかかったステップ数は4です
# エピソード:24
# 0.047065540364870206
# 迷路を解くのにかかったステップ数は4です
# エピソード:25
# 0.0458164045333353
# 迷路を解くのにかかったステップ数は4です
# エピソード:26
# 0.044535546687028804
# 迷路を解くのにかかったステップ数は4です
# エピソード:27
# 0.04322845895000205
# 迷路を解くのにかかったステップ数は4です
# エピソード:28
# 0.041900629906862163
# 迷路を解くのにかかったステップ数は4です
# エピソード:29
# 0.04055746829274792
# 迷路を解くのにかかったステップ数は4です
# エピソード:30
# 0.039204238623389454
# 迷路を解くのにかかったステップ数は4です
# エピソード:31
# 0.03784600803276045
# 迷路を解くのにかかったステップ数は4です
# エピソード:32
# 0.03648760346802571
# 迷路を解くのにかかったステップ数は4です
# エピソード:33
# 0.03513357832460845
# 迷路を解くのにかかったステップ数は4です
# エピソード:34
# 0.03378818757670882
# 迷路を解くのにかかったステップ数は4です
# エピソード:35
# 0.03245537046102431
# 迷路を解くのにかかったステップ数は4です
# エピソード:36
# 0.03113873979606835
# 迷路を解くのにかかったステップ数は4です
# エピソード:37
# 0.02984157706017576
# 迷路を解くのにかかったステップ数は4です
# エピソード:38
# 0.028566832403008724
# 迷路を解くのにかかったステップ数は4です
# エピソード:39
# 0.02731712882423426
# 迷路を解くのにかかったステップ数は4です
# エピソード:40
# 0.026094769815893204
# 迷路を解くのにかかったステップ数は4です
# エピソード:41
# 0.024901749829429054
# 迷路を解くのにかかったステップ数は4です
# エピソード:42
# 0.023739766992556532
# 迷路を解くのにかかったステップ数は4です
# エピソード:43
# 0.022610237563743363
# 迷路を解くのにかかったステップ数は4です
# エピソード:44
# 0.021514311672058306
# 迷路を解くのにかかったステップ数は4です
# エピソード:45
# 0.020452889946824038
# 迷路を解くのにかかったステップ数は4です
# エピソード:46
# 0.019426640694422348
# 迷路を解くのにかかったステップ数は4です
# エピソード:47
# 0.018436017328505305
# 迷路を解くのにかかったステップ数は4です
# エピソード:48
# 0.01748127580462866
# 迷路を解くのにかかったステップ数は4です
# エピソード:49
# 0.016562491850950933
# 迷路を解くのにかかったステップ数は4です
# エピソード:50
# 0.015679577823239477
# 迷路を解くのにかかったステップ数は4です
# エピソード:51
# 0.014832299045105413
# 迷路を解くのにかかったステップ数は4です
# エピソード:52
# 0.014020289523391405
# 迷路を解くのにかかったステップ数は4です
# エピソード:53
# 0.01324306695415467
# 迷路を解くのにかかったステップ数は4です
# エピソード:54
# 0.01250004695697382
# 迷路を解くのにかかったステップ数は4です
# エピソード:55
# 0.011790556494630455
# 迷路を解くのにかかったステップ数は4です
# エピソード:56
# 0.011113846451794362
# 迷路を解くのにかかったステップ数は4です
# エピソード:57
# 0.010469103360470577
# 迷路を解くのにかかったステップ数は4です
# エピソード:58
# 0.009855460271845362
# 迷路を解くのにかかったステップ数は4です
# エピソード:59
# 0.009272006784061593
# 迷路を解くのにかかったステップ数は4です
# エピソード:60
# 0.008717798243563335
# 迷路を解くのにかかったステップ数は4です
# エピソード:61
# 0.008191864144184713
# 迷路を解くのにかかったステップ数は4です
# エピソード:62
# 0.007693215753313387
# 迷路を解くのにかかったステップ数は4です
# エピソード:63
# 0.00722085299839792
# 迷路を解くのにかかったステップ数は4です
# エピソード:64
# 0.006773770649970756
# 迷路を解くのにかかったステップ数は4です
# エピソード:65
# 0.006350963839342527
# 迷路を解くのにかかったステップ数は4です
# エピソード:66
# 0.005951432950354829
# 迷路を解くのにかかったステップ数は4です
# エピソード:67
# 0.005574187925138641
# 迷路を解くのにかかったステップ数は4です
# エピソード:68
# 0.005218252023851622
# 迷路を解くのにかかったステップ数は4です
# エピソード:69
# 0.004882665077934001
# 迷路を解くのにかかったステップ数は4です
# エピソード:70
# 0.004566486275620063
# 迷路を解くのにかかったステップ数は4です
# エピソード:71
# 0.0042687965173406894
# 迷路を解くのにかかったステップ数は4です
# エピソード:72
# 0.003988700377319798
# 迷路を解くのにかかったステップ数は4です
# エピソード:73
# 0.0037253277061509715
# 迷路を解くのにかかったステップ数は4です
# エピソード:74
# 0.003477834907500088
# 迷路を解くのにかかったステップ数は4です
# エピソード:75
# 0.003245405920344391
# 迷路を解くのにかかったステップ数は4です
# エピソード:76
# 0.003027252936365854
# 迷路を解くのにかかったステップ数は4です
# エピソード:77
# 0.0028226168803080487
# 迷路を解くのにかかったステップ数は4です
# エピソード:78
# 0.0026307676792841628
# 迷路を解くのにかかったステップ数は4です
# エピソード:79
# 0.0024510043452308228
# 迷路を解くのにかかったステップ数は4です
# エピソード:80
# 0.0022826548929388846
# 迷路を解くのにかかったステップ数は4です
# エピソード:81
# 0.0021250761143802865
# 迷路を解くのにかかったステップ数は4です
# エピソード:82
# 0.001977653228400711
# 迷路を解くのにかかったステップ数は4です
# エピソード:83
# 0.0018397994232586257
# 迷路を解くのにかかったステップ数は4です
# エピソード:84
# 0.0017109553079791562
# 迷路を解くのにかかったステップ数は4です
# エピソード:85
# 0.0015905882870593802
# 迷路を解くのにかかったステップ数は4です
# エピソード:86
# 0.0014781918717038378
# 迷路を解くのにかかったステップ数は4です
# エピソード:87
# 0.0013732849394921809
# 迷路を解くのにかかったステップ数は4です
# エピソード:88
# 0.0012754109531916136
# 迷路を解くのにかかったステップ数は4です
# エピソード:89
# 0.0011841371483061192
# 迷路を解くのにかかったステップ数は4です
# エピソード:90
# 0.0010990536979252896
# 迷路を解くのにかかったステップ数は4です
# エピソード:91
# 0.001019772862469237
# 迷路を解くのにかかったステップ数は4です
# エピソード:92
# 0.0009459281310438827
# 迷路を解くのにかかったステップ数は4です
# エピソード:93
# 0.0008771733603041287
# 迷路を解くのにかかったステップ数は4です
# エピソード:94
# 0.0008131819159731268
# 迷路を解くのにかかったステップ数は4です
# エピソード:95
# 0.0007536458214827402
# 迷路を解くのにかかったステップ数は4です
# エピソード:96
# 0.0006982749175779013
# 迷路を解くのにかかったステップ数は4です
# エピソード:97
# 0.0006467960361561387
# 迷路を解くのにかかったステップ数は4です
# エピソード:98
# 0.0005989521911071716
# 迷路を解くのにかかったステップ数は4です
# エピソード:99
# 0.0005545017884494019
# 迷路を解くのにかかったステップ数は4です
# エピソード:100
# 0.0005132178576453539
# 迷路を解くのにかかったステップ数は4です

# %%
# エージェントの移動の様子を可視化します
# 参考URL http://louistiao.me/posts/notebooks/embedding-matplotlib-animations-in-jupyter-notebooks/
from matplotlib import animation
from IPython.display import HTML

def init():
    # 背景画像の初期化
    line.set_data([], [])
    return (line,)

def animate(i):
    # フレームごとの描画内容
    state = s_a_history[i][0]  # 現在の場所を描く
    x = (state % 3) + 0.5  # 状態のx座標は、3で割った余り+0.5
    y = 2.5 - int(state / 3)  # y座標は3で割った商を2.5から引く
    line.set_data(x, y)
    return (line,)

#　初期化関数とフレームごとの描画関数を用いて動画を作成
anim = animation.FuncAnimation(fig, animate, init_func=init, frames=len(
    s_a_history), interval=200, repeat=False)
 
HTML(anim.to_html5_video())
# Out:
# <video width="360" height="360" controls autoplay>
#   <source type="video/mp4" src="...">
#   Your browser does not support the video tag.
# </video>
